# %% [markdown]
# # Importing packages

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from xgboost import XGBRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split, KFold, cross_validate, GridSearchCV, TimeSeriesSplit

# %% [markdown]
# # Importing the data

# %%
data_path = r"C:\Users\titou\Desktop\python_test_files\ML_classic\hackathon\store_sales_forecasting\data"

input_data_df = pd.read_csv(data_path + r'\train.csv')
#test_data_df = pd.read_csv(data_path + r'\test.csv')
holiday_df = pd.read_csv(data_path + r'\holidays_events.csv')
oil_df = pd.read_csv(data_path + r'\oil.csv')
stores_df = pd.read_csv(data_path + r'\stores.csv')
#transaction_df = pd.read_csv(data_path + r'\transactions.csv')

# %%
print("input data:", input_data_df.info(), "\n")
print("holiday:",holiday_df.info(), "\n")
print("oil:",oil_df.info(), "\n")
print("stores:",stores_df.info(), "\n")
#print("transaction:",transaction_df.info(), "\n")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000888 entries, 0 to 3000887
# Data columns (total 6 columns):
#  #   Column       Dtype
# ---  ------       -----
#  0   id           int64
#  1   date         object
#  2   store_nbr    int64
#  3   family       object
#  4   sales        float64
#  5   onpromotion  int64
# dtypes: float64(1), int64(3), object(2)
# memory usage: 137.4+ MB
# input data: None
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 350 entries, 0 to 349
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         350 non-null    object
#  1   type         350 non-null    object
#  2   locale       350 non-null    object
#  3   locale_name  350 non-null    object
#  4   description  350 non-null    object
#  5   transferred  350 non-null    bool
# dtypes: bool(1), object(5)
# memory usage: 14.1+ KB
# holiday: None
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1218 entries, 0 to 1217
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date        1218 non-null   object
#  1   dcoilwtico  1175 non-null   float64
# dtypes: float64(1), object(1)
# memory usage: 19.2+ KB
# oil: None
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54 entries, 0 to 53
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   store_nbr  54 non-null     int64
#  1   city       54 non-null     object
#  2   state      54 non-null     object
#  3   type       54 non-null     object
#  4   cluster    54 non-null     int64
# dtypes: int64(2), object(3)
# memory usage: 2.2+ KB
# stores: None

# %%
input_data_extended_df = pd.merge
# Out:
#    id        date  store_nbr      family  sales  onpromotion
# 0   0  2013-01-01          1  AUTOMOTIVE    0.0            0
# 1   1  2013-01-01          1   BABY CARE    0.0            0
# 2   2  2013-01-01          1      BEAUTY    0.0            0
# 3   3  2013-01-01          1   BEVERAGES    0.0            0
# 4   4  2013-01-01          1       BOOKS    0.0            0

# %%
input_data_df.head()
# Out:
#    id        date  store_nbr      family  sales  onpromotion
# 0   0  2013-01-01          1  AUTOMOTIVE    0.0            0
# 1   1  2013-01-01          1   BABY CARE    0.0            0
# 2   2  2013-01-01          1      BEAUTY    0.0            0
# 3   3  2013-01-01          1   BEVERAGES    0.0            0
# 4   4  2013-01-01          1       BOOKS    0.0            0

# %%
holiday_df.head()
# Out:
#          date     type  ...                    description transferred
# 0  2012-03-02  Holiday  ...             Fundacion de Manta       False
# 1  2012-04-01  Holiday  ...  Provincializacion de Cotopaxi       False
# 2  2012-04-12  Holiday  ...            Fundacion de Cuenca       False
# 3  2012-04-14  Holiday  ...      Cantonizacion de Libertad       False
# 4  2012-04-21  Holiday  ...      Cantonizacion de Riobamba       False
#
# [5 rows x 6 columns]

# %%
stores_df.head()
# Out:
#    store_nbr           city                           state type  cluster
# 0          1          Quito                       Pichincha    D       13
# 1          2          Quito                       Pichincha    D       13
# 2          3          Quito                       Pichincha    D        8
# 3          4          Quito                       Pichincha    D        9
# 4          5  Santo Domingo  Santo Domingo de los Tsachilas    D        4

# %%
oil_df.head()
# Out:
#          date  dcoilwtico
# 0  2013-01-01         NaN
# 1  2013-01-02       93.14
# 2  2013-01-03       92.97
# 3  2013-01-04       93.12
# 4  2013-01-07       93.20

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# ### Cleaning holiday

# %%
holiday_df_clean = holiday_df[["date","type", "transferred"]].copy()
holiday_df_clean[["type", "transferred"]] = holiday_df[["type", "transferred"]].astype("category")
holiday_df_clean["type"] = holiday_df_clean["type"].cat.codes + 1
holiday_df_clean["transferred"] = holiday_df_clean["transferred"].cat.codes

# %%
holiday_df_clean = holiday_df_clean.rename(columns = {"type":"holiday_type","transferred": "holiday_transferred"})
holiday_df_clean
# Out:
#            date  holiday_type  holiday_transferred
# 0    2012-03-02             4                    0
# 1    2012-04-01             4                    0
# 2    2012-04-12             4                    0
# 3    2012-04-14             4                    0
# 4    2012-04-21             4                    0
# ..          ...           ...                  ...
# 345  2017-12-22             1                    0
# 346  2017-12-23             1                    0
# 347  2017-12-24             1                    0
# 348  2017-12-25             4                    0
# 349  2017-12-26             1                    0
#
# [350 rows x 3 columns]

# %% [markdown]
# ### Cleaning oil

# %%
oil_df_clean = oil_df.ffill().bfill()
# Out:
# date          False
# dcoilwtico     True
# dtype: bool

# %% [markdown]
# ### Cleaning store

# %%
stores_df_clean = stores_df.copy()
stores_df_clean[["city", "state", "type", "cluster"]] = stores_df_clean[["city", "state", "type", "cluster"]].astype("category")
for col in ["city", "state", "type", "cluster"]:
    stores_df_clean[col] = stores_df_clean[col].cat.codes

# %% [markdown]
# # Data merging

# %%
print(input_data_df.isna().any(axis=0))
input_data_df.head()
# Out:
# id             False
# date           False
# store_nbr      False
# family         False
# sales          False
# onpromotion    False
# dtype: bool
#    id        date  store_nbr      family  sales  onpromotion
# 0   0  2013-01-01          1  AUTOMOTIVE    0.0            0
# 1   1  2013-01-01          1   BABY CARE    0.0            0
# 2   2  2013-01-01          1      BEAUTY    0.0            0
# 3   3  2013-01-01          1   BEVERAGES    0.0            0
# 4   4  2013-01-01          1       BOOKS    0.0            0

# %%
print(holiday_df_clean.isna().any(axis=0))
holiday_df_clean.head()
# Out:
# date                   False
# holiday_type           False
# holiday_transferred    False
# dtype: bool
#          date  holiday_type  holiday_transferred
# 0  2012-03-02             4                    0
# 1  2012-04-01             4                    0
# 2  2012-04-12             4                    0
# 3  2012-04-14             4                    0
# 4  2012-04-21             4                    0

# %%
print(oil_df_clean.isna().any(axis=0))
oil_df_clean.head()
# Out:
# date          False
# dcoilwtico    False
# dtype: bool
#          date  dcoilwtico
# 0  2013-01-01       93.14
# 1  2013-01-02       93.14
# 2  2013-01-03       92.97
# 3  2013-01-04       93.12
# 4  2013-01-07       93.20

# %%
print(stores_df_clean.isna().any(axis=0))
stores_df_clean.head()
# Out:
# store_nbr    False
# city         False
# state        False
# type         False
# cluster      False
# dtype: bool
#    store_nbr  city  state  type  cluster
# 0          1    18     12     3       12
# 1          2    18     12     3       12
# 2          3    18     12     3        7
# 3          4    18     12     3        8
# 4          5    21     14     3        3

# %%
input_data_merged_df = input_data_df.merge(holiday_df_clean, on="date", how="left")
input_data_merged_df = input_data_merged_df.fillna(0)
input_data_merged_df.isna().any(axis=0)
# Out:
# id                     False
# date                   False
# store_nbr              False
# family                 False
# sales                  False
# onpromotion            False
# holiday_type           False
# holiday_transferred    False
# dtype: bool

# %%
input_data_merged_df = input_data_merged_df.merge(oil_df_clean, on="date", how="left")
input_data_merged_df["dcoilwtico"] = input_data_merged_df["dcoilwtico"].ffill()
input_data_merged_df.head()
# Out:
#    id        date  store_nbr  ... holiday_type  holiday_transferred  dcoilwtico
# 0   0  2013-01-01          1  ...          4.0                  0.0       93.14
# 1   1  2013-01-01          1  ...          4.0                  0.0       93.14
# 2   2  2013-01-01          1  ...          4.0                  0.0       93.14
# 3   3  2013-01-01          1  ...          4.0                  0.0       93.14
# 4   4  2013-01-01          1  ...          4.0                  0.0       93.14
#
# [5 rows x 9 columns]

# %%
input_data_merged_df.isna().any(axis=0)
# Out:
# id                     False
# date                   False
# store_nbr              False
# family                 False
# sales                  False
# onpromotion            False
# holiday_type           False
# holiday_transferred    False
# dcoilwtico             False
# dtype: bool

# %%
input_data_merged_df = input_data_merged_df.merge(stores_df_clean, on="store_nbr", how="left")
input_data_merged_df.isna().any(axis=0)
# Out:
# id                     False
# date                   False
# store_nbr              False
# family                 False
# sales                  False
# onpromotion            False
# holiday_type           False
# holiday_transferred    False
# dcoilwtico             False
# city                   False
# state                  False
# type                   False
# cluster                False
# dtype: bool

# %%
input_data_merged_df["family"] = input_data_merged_df["family"].astype("category")
input_data_merged_df["family"] = input_data_merged_df["family"].cat.codes
input_data_merged_df = input_data_merged_df.drop(columns=["date", "id"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[160], line 3
#       1 input_data_merged_df["family"] = input_data_merged_df["family"].astype("category")
#       2 input_data_merged_df["family"] = input_data_merged_df["family"].cat.codes
# ----> 3 input_data_merged_df = input_data_merged_df.drop(columns=["date", "id"])
#
# File c:\Users\titou\Desktop\python_test_files\virtual_environments\ml_env\Lib\site-packages\pandas\core\frame.py:5603, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5455 def drop(
#    5456     self,
#    5457     labels: IndexLabel | None = None,
#    (...)   5464     errors: IgnoreRaise = "raise",
#    5465 ) -> DataFrame | None:
#    5466     """
#    5467     Drop specified labels from rows or columns.
#    5468
#    (...)   5601             weight  1.0     0.8
#    5602     """
# -> 5603     return super().drop(
#    5604         labels=labels,
#    5605         axis=axis,
#    5606         index=index,
#    5607         columns=columns,
#    5608         level=level,
#    5609         inplace=inplace,
#    5610         errors=errors,
#    5611     )
#
# File c:\Users\titou\Desktop\python_test_files\virtual_environments\ml_env\Lib\site-packages\pandas\core\generic.py:4810, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4808 for axis, labels in axes.items():
#    4809     if labels is not None:
# -> 4810         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4812 if inplace:
#    4813     self._update_inplace(obj)
#
# File c:\Users\titou\Desktop\python_test_files\virtual_environments\ml_env\Lib\site-packages\pandas\core\generic.py:4852, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4850         new_axis = axis.drop(labels, level=level, errors=errors)
#    4851     else:
# -> 4852         new_axis = axis.drop(labels, errors=errors)
#    4853     indexer = axis.get_indexer(new_axis)
#    4855 # Case for non-unique axis
#    4856 else:
#
# File c:\Users\titou\Desktop\python_test_files\virtual_environments\ml_env\Lib\site-packages\pandas\core\indexes\base.py:7136, in Index.drop(self, labels, errors)
#    7134 if mask.any():
#    7135     if errors != "ignore":
# -> 7136         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7137     indexer = indexer[~mask]
#    7138 return self.delete(indexer)
#
# KeyError: "['date'] not found in axis"

# %%
input_data_merged_df.head()
# Out:
#    store_nbr  family  sales  onpromotion  ...  city  state  type  cluster
# 0          1       0    0.0            0  ...    18     12     3       12
# 1          1       1    0.0            0  ...    18     12     3       12
# 2          1       2    0.0            0  ...    18     12     3       12
# 3          1       3    0.0            0  ...    18     12     3       12
# 4          1       4    0.0            0  ...    18     12     3       12
#
# [5 rows x 11 columns]

# %% [markdown]
# # Building the model

# %%
X = input_data_merged_df.drop(columns="sales").values
y = input_data_merged_df["sales"].values

# %%
X.shape
# Out:
# (3054348, 10)

# %%
y.shape
# Out:
# (3054348,)
